# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Beispieldaten erzeugen
X = np.linspace(0, 1, 100)
y = 3 * X + 1 + np.random.rand(X.shape[0])

# Beispieldaten visualisieren
plt.plot(X, y, ".")
plt.ylim(bottom = 0);

# %%
from sklearn.linear_model import LinearRegression

modell = LinearRegression(fit_intercept = True)
modell.fit(X.reshape(-1, 1), y)

modell.coef_, modell.intercept_
# Out:
# (array([2.95818394]), 1.5078199091405966)

# %%
print(f"Modell: y_hat = {round(modell.coef_[0], 2)} * x + {round(modell.intercept_, 2)}")
# Out:
# Modell: y_hat = 2.96 * x + 1.51

# %%
y_hat = modell.predict(X.reshape(-1, 1))
se = sum((y - y_hat)**2)
mse = se/len(y)
rmse = np.sqrt(mse)

print(f"Sum of Squared Errors: {round(np.sum(se), 3)}")
print(f"Mean Squared Error: {round(mse, 3)}")
print(f"Root Mean Squared Error: {round(rmse, 3)}")
# Out:
# Sum of Squared Errors: 8.429
# Mean Squared Error: 0.084
# Root Mean Squared Error: 0.29

# %%
plt.plot(X, y, ".", label = "Daten")
plt.plot(X, y_hat, label = "Modell")
plt.ylim(bottom = 0)
plt.legend();

# %%
## neuer Abschnitt

# %%
# Beispieldaten erzeugen
X = np.linspace(0, 1, 100)
y = 4 * X**2 + .5 * X + np.random.rand(X.shape[0])

# Beispieldaten visualisieren
plt.plot(X, y, ".")
plt.ylim(bottom = 0);

# %%
modell_1d = LinearRegression(fit_intercept = True)
modell_1d.fit(X.reshape(-1, 1), y)

modell_1d.coef_, modell_1d.intercept_
# Out:
# (array([4.3812464]), -0.1837978783249814)

# %%
print(f"Modell: y_hat = {round(modell_1d.coef_[0], 2)} * x + {round(modell_1d.intercept_, 2)}")
# Out:
# Modell: y_hat = 4.38 * x + -0.18

# %%
def model_summary(modell: LinearRegression or sklearn.pipeline.Pipeline, X: np.ndarray, y: np.ndarray) -> None:
    """Prints summary of model metrics and plots model against data set"""
    y_hat = modell.predict(X.reshape(-1, 1))
    
    se = sum((y - y_hat)**2)
    mse = se/len(y)
    rmse = np.sqrt(mse)

    print(f"Sum of Squared Errors: {round(np.sum(se), 3)}")
    print(f"Mean Squared Error: {round(mse, 3)}")
    print(f"Root Mean Squared Error: {round(rmse, 3)}")

    plt.plot(X, y, '.', label = "Daten")
    plt.plot(X, y_hat, label = "Modell")
    plt.legend();

# %%
model_summary(modell_1d, X, y)
# Out:
# Sum of Squared Errors: 19.139
# Mean Squared Error: 0.191
# Root Mean Squared Error: 0.437

# %%
## neuer Abschnitt

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import PolynomialFeatures

pipe_3d = Pipeline([
    ("poly_transform_3d", PolynomialFeatures(3)), # Grad des Polynoms
    ("modell_3d", LinearRegression())
])

pipe_3d.fit(X.reshape(-1, 1), y)
# Out:
# Pipeline(steps=[('poly_transform_3d', PolynomialFeatures(degree=3)),
#                 ('modell_3d', LinearRegression())])

# %%
model_summary(pipe_3d, X, y)
# Out:
# Sum of Squared Errors: 8.344
# Mean Squared Error: 0.083
# Root Mean Squared Error: 0.289

# %%
pipe_100d = Pipeline([
    ("poly_transform_100d", PolynomialFeatures(100)),
    ("modell_100d", LinearRegression())
])

pipe_100d.fit(X.reshape(-1, 1), y)
# Out:
# Pipeline(steps=[('poly_transform_100d', PolynomialFeatures(degree=100)),
#                 ('modell_100d', LinearRegression())])

# %%
model_summary(pipe_100d, X, y)
# Out:
# Sum of Squared Errors: 6.395
# Mean Squared Error: 0.064
# Root Mean Squared Error: 0.253

# %%
## neuer Abschnitt

# %%
# Testdaten erzeugen
X_test = np.linspace(-1, 1, 100)
y_test = 4 * X_test**2 + .5 * X_test + np.random.rand(X_test.shape[0]) # Die gleiche Funktion wie vorhin!

# Beispieldaten visualisieren
plt.plot(X_test, y_test, ".")
plt.ylim(bottom = 0);

# %%
model_summary(modell_1d, X_test, y_test)
# Out:
# Sum of Squared Errors: 1101.765
# Mean Squared Error: 11.018
# Root Mean Squared Error: 3.319

# %%
model_summary(pipe_3d, X_test, y_test)
# Out:
# Sum of Squared Errors: 188.421
# Mean Squared Error: 1.884
# Root Mean Squared Error: 1.373

# %%
model_summary(pipe_100d, X_test, y_test)
# Out:
# Sum of Squared Errors: 1.4029138757447345e+27
# Mean Squared Error: 1.4029138757447344e+25
# Root Mean Squared Error: 3745549193035.294

# %%
## neuer Abschnitt

# %%
pipe_2d = Pipeline([
    ("poly_transform_2d", PolynomialFeatures(2)),
    ("modell_2d", LinearRegression())
])

pipe_2d.fit(X.reshape(-1, 1), y)
# Out:
# Pipeline(steps=[('poly_transform_2d', PolynomialFeatures()),
#                 ('modell_2d', LinearRegression())])

# %%
model_summary(pipe_2d, X, y)
# Out:
# Sum of Squared Errors: 8.387
# Mean Squared Error: 0.084
# Root Mean Squared Error: 0.29

# %%
model_summary(pipe_2d, X_test, y_test)
# Out:
# Sum of Squared Errors: 15.083
# Mean Squared Error: 0.151
# Root Mean Squared Error: 0.388

# %%
## neuer Abschnitt

# %%
def compare_metrics(modell: LinearRegression or sklearn.pipeline.Pipeline) -> None:
    """Compares error metrics between training and test trials"""
    y_hat = modell.predict(X.reshape(-1, 1))
    se = sum((y - y_hat)**2)
    mse = se/len(y)
    rmse = np.sqrt(mse)
  
    y_hat_test = modell.predict(X_test.reshape(-1, 1))
    se_test = sum((y_test - y_hat_test)**2)
    mse_test = se_test/len(y_test)
    rmse_test = np.sqrt(mse_test)

    print(f"Sum of Squared Errors: {round(np.sum(se), 3)} (training) vs. {round(np.sum(se_test), 3)} (test)")
    print(f"Mean Squared Error: {round(mse, 3)} (training) vs. {round(np.sum(mse_test), 3)} (test)")
    print(f"Root Mean Squared Error: {round(rmse, 3)} (training) vs. {round(np.sum(rmse_test), 3)} (test)")

# %%
def plot_preds(model: LinearRegression or sklearn.pipeline.Pipeline) -> None:
    """Plots model predictions against actual test labels"""
    plt.plot(y_test, model.predict(X_test.reshape(-1, 1)), '.')
    plt.xlabel("y_test")
    plt.ylabel("model_prediction");

# %%
compare_metrics(modell_1d)
# Out:
# Sum of Squared Errors: 19.139 (training) vs. 1101.765 (test)
# Mean Squared Error: 0.191 (training) vs. 11.018 (test)
# Root Mean Squared Error: 0.437 (training) vs. 3.319 (test)

# %%
plot_preds(modell_1d)

# %%
compare_metrics(pipe_3d)
# Out:
# Sum of Squared Errors: 8.344 (training) vs. 188.421 (test)
# Mean Squared Error: 0.083 (training) vs. 1.884 (test)
# Root Mean Squared Error: 0.289 (training) vs. 1.373 (test)

# %%
plot_preds(pipe_3d)

# %%
compare_metrics(pipe_100d)
# Out:
# Sum of Squared Errors: 6.395 (training) vs. 1.4029138757447345e+27 (test)
# Mean Squared Error: 0.064 (training) vs. 1.4029138757447344e+25 (test)
# Root Mean Squared Error: 0.253 (training) vs. 3745549193035.294 (test)

# %%
plot_preds(pipe_100d)

# %%
compare_metrics(pipe_2d)
# Out:
# Sum of Squared Errors: 8.387 (training) vs. 15.083 (test)
# Mean Squared Error: 0.084 (training) vs. 0.151 (test)
# Root Mean Squared Error: 0.29 (training) vs. 0.388 (test)

# %%
plot_preds(pipe_2d)
